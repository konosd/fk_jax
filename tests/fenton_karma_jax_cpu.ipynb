# %% [markdown]
# <a href="https://colab.research.google.com/github/epignatelli/fenton_karma_jax/blob/master/fenton_karma_jax_cpu.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/epignatelli/fenton_karma_jax.git
# Out:
# Cloning into 'fenton_karma_jax'...
# remote: Enumerating objects: 183, done.
# remote: Counting objects: 100% (183/183), done.
# remote: Compressing objects: 100% (161/161), done.
# remote: Total 183 (delta 92), reused 32 (delta 12), pack-reused 0
# Receiving objects: 100% (183/183), 383.07 KiB | 14.19 MiB/s, done.
# Resolving deltas: 100% (92/92), done.

# %%
from fk import params
from fk import model
import matplotlib.pyplot as plt
import jax
import jax.numpy as np

# %%
# geometry
shape = (1024, 1024)
dt = 0.01
dx = 0.01

# diffusivity map
d = 0.05
D = np.ones(shape) * d

# stimuli
field = np.zeros(shape)
field = jax.ops.index_update(field, jax.ops.index[0:20], .8)
s1 = {
    "field": field,
    "start": 0,
    "duration": 2,
    "period": 0  # non-cyclic
}

field2 = np.zeros(shape)
field2 = jax.ops.index_update(field, jax.ops.index[:, -20:], .5)
s2 = {
    "field": field2,
    "start": 200,
    "duration": 2,
    "period": 0  # non-cyclic
}

field3 = np.zeros(shape)
field3 = jax.ops.index_update(field, jax.ops.index[40:60], .5)
s3 = {
    "field": field3,
    "start": 360,
    "duration": 15,
    "period": 0  # non-cyclic
}

# %%
# %%timeit -n1
state = model.forward(shape, np.arange(0,1000,100), params.params_test(), D, [s1, s2], dt, dx)[0].block_until_ready()
# Out:
# Solving at: 100ms/900ms
# Solving at: 200ms/900ms
# Solving at: 300ms/900ms
# Solving at: 400ms/900ms
# Solving at: 500ms/900ms
# Solving at: 600ms/900ms
# Solving at: 700ms/900ms
# Solving at: 800ms/900ms
# Solving at: 900ms/900ms
# Solving at: 100ms/900ms
# Solving at: 200ms/900ms
# Solving at: 300ms/900ms
# Solving at: 400ms/900ms
# Solving at: 500ms/900ms
# Solving at: 600ms/900ms
# Solving at: 700ms/900ms
# Solving at: 800ms/900ms
# Solving at: 900ms/900ms
# Solving at: 100ms/900ms
# Solving at: 200ms/900ms
# Solving at: 300ms/900ms
# Solving at: 400ms/900ms
# Solving at: 500ms/900ms
# Solving at: 600ms/900ms
# Solving at: 700ms/900ms
# Solving at: 800ms/900ms
# Solving at: 900ms/900ms
# Solving at: 100ms/900ms
# Solving at: 200ms/900ms
# Solving at: 300ms/900ms
# Solving at: 400ms/900ms
# Solving at: 500ms/900ms
# Solving at: 600ms/900ms
# Solving at: 700ms/900ms
# Solving at: 800ms/900ms
# Solving at: 900ms/900ms
# Solving at: 100ms/900ms
# Solving at: 200ms/900ms
# Solving at: 300ms/900ms
# Solving at: 400ms/900ms
# Solving at: 500ms/900ms
# Solving at: 600ms/900ms
# Solving at: 700ms/900ms
# Solving at: 800ms/900ms
# Solving at: 900ms/900ms
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-23-718e7926dc33> in <module>
# ----> 1 get_ipython().run_cell_magic('timeit', '-n1', 'state = model.forward(shape, np.arange(0,1000,100), params.params_test(), D, [s1, s2], dt, dx)[0].block_until_ready()\n')
#
# /opt/anaconda3/envs/cardio/lib/python3.7/site-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2360             with self.builtin_trap:
#    2361                 args = (magic_arg_s, cell)
# -> 2362                 result = fn(*args, **kwargs)
#    2363             return result
#    2364
#
# <decorator-gen-60> in timeit(self, line, cell, local_ns)
#
# /opt/anaconda3/envs/cardio/lib/python3.7/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# /opt/anaconda3/envs/cardio/lib/python3.7/site-packages/IPython/core/magics/execution.py in timeit(self, line, cell, local_ns)
#    1162                     break
#    1163
# -> 1164         all_runs = timer.repeat(repeat, number)
#    1165         best = min(all_runs) / number
#    1166         worst = max(all_runs) / number
#
# /opt/anaconda3/envs/cardio/lib/python3.7/timeit.py in repeat(self, repeat, number)
#     202         r = []
#     203         for i in range(repeat):
# --> 204             t = self.timeit(number)
#     205             r.append(t)
#     206         return r
#
# /opt/anaconda3/envs/cardio/lib/python3.7/site-packages/IPython/core/magics/execution.py in timeit(self, number)
#     167         gc.disable()
#     168         try:
# --> 169             timing = self.inner(it, self.timer)
#     170         finally:
#     171             if gcold:
#
# <magic-timeit> in inner(_it, _timer)
#
# /opt/anaconda3/envs/cardio/lib/python3.7/site-packages/fk/model.py in forward(shape, checkpoints, cell_parameters, diffusivity, stimuli, dt, dx)
#      35         print("Solving at: %dms/%dms\t\t" % (checkpoints[i + 1], checkpoints[-1]), end="\r")
#      36         state = _forward(state, checkpoints[i], checkpoints[i + 1], cell_parameters, np.ones(shape) * diffusivity, stimuli, dt, dx)
# ---> 37         plot.show(state)
#      38         states.append(state[2])
#      39     return states
#
# /opt/anaconda3/envs/cardio/lib/python3.7/site-packages/fk/plot.py in show(state, **kwargs)
#      30     vmax = kwargs.pop("vmax", 1)
#      31     cmap = kwargs.pop("cmap", "RdBu")
# ---> 32     im = ax[0].imshow(state[0], vmin=vmin, vmax=vmax, cmap=cmap, **kwargs)
#      33     plt.colorbar(im, ax=ax[0])
#      34     ax[0].set_title("v")
#
# /opt/anaconda3/envs/cardio/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1563     def inner(ax, *args, data=None, **kwargs):
#    1564         if data is None:
# -> 1565             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1566
#    1567         bound = new_sig.bind(ax, *args, **kwargs)
#
# /opt/anaconda3/envs/cardio/lib/python3.7/site-packages/matplotlib/cbook/deprecation.py in wrapper(*args, **kwargs)
#     356                 f"%(removal)s.  If any parameter follows {name!r}, they "
#     357                 f"should be pass as keyword, not positionally.")
# --> 358         return func(*args, **kwargs)
#     359
#     360     return wrapper
#
# /opt/anaconda3/envs/cardio/lib/python3.7/site-packages/matplotlib/cbook/deprecation.py in wrapper(*args, **kwargs)
#     356                 f"%(removal)s.  If any parameter follows {name!r}, they "
#     357                 f"should be pass as keyword, not positionally.")
# --> 358         return func(*args, **kwargs)
#     359
#     360     return wrapper
#
# /opt/anaconda3/envs/cardio/lib/python3.7/site-packages/matplotlib/axes/_axes.py in imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, **kwargs)
#    5624                               resample=resample, **kwargs)
#    5625
# -> 5626         im.set_data(X)
#    5627         im.set_alpha(alpha)
#    5628         if im.get_clip_path() is None:
#
# /opt/anaconda3/envs/cardio/lib/python3.7/site-packages/matplotlib/image.py in set_data(self, A)
#     687             if isinstance(A, Image.Image):
#     688                 A = pil_to_array(A)  # Needed e.g. to apply png palette.
# --> 689         self._A = cbook.safe_masked_invalid(A, copy=True)
#     690
#     691         if (self._A.dtype != np.uint8 and
#
# /opt/anaconda3/envs/cardio/lib/python3.7/site-packages/matplotlib/cbook/__init__.py in safe_masked_invalid(x, copy)
#     704
#     705 def safe_masked_invalid(x, copy=False):
# --> 706     x = np.array(x, subok=True, copy=copy)
#     707     if not x.dtype.isnative:
#     708         # Note that the argument to `byteswap` is 'inplace',
#
# /opt/anaconda3/envs/cardio/lib/python3.7/site-packages/jax/interpreters/xla.py in __array__(self, dtype, context)
#    1058
#    1059   def __array__(self, dtype=None, context=None):
# -> 1060     return onp.asarray(self._value, dtype=dtype)
#    1061
#    1062   @property
#
# /opt/anaconda3/envs/cardio/lib/python3.7/site-packages/jax/interpreters/xla.py in _value(self)
#     963         self._npy_value = lazy.eval_lexpr(self._lazy_expr, None)
#     964       else:
# --> 965         self._npy_value = _force(self).device_buffer.to_py()
#     966       self._npy_value.flags.writeable = False
#     967     return self._npy_value
#
# KeyboardInterrupt:

# %%
# %%timeit -n10
state = model.init(shape)
p = params.params_test()
for t in range(1000):
    state = model.step(state, t * dt, p, D, [s1, s2], dt)
state[0].block_until_ready()
# Out:
# 10 loops, best of 3: 1.86 s per loop

# %%
# !lscpu
# Out:
# Architecture:        x86_64
# CPU op-mode(s):      32-bit, 64-bit
# Byte Order:          Little Endian
# CPU(s):              2
# On-line CPU(s) list: 0,1
# Thread(s) per core:  2
# Core(s) per socket:  1
# Socket(s):           1
# NUMA node(s):        1
# Vendor ID:           GenuineIntel
# CPU family:          6
# Model:               63
# Model name:          Intel(R) Xeon(R) CPU @ 2.30GHz
# Stepping:            0
# CPU MHz:             2300.000
# BogoMIPS:            4600.00
# Hypervisor vendor:   KVM
# Virtualization type: full
# L1d cache:           32K
# L1i cache:           32K
# L2 cache:            256K
# L3 cache:            46080K
# NUMA node0 CPU(s):   0,1
# Flags:               fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 avx2 smep bmi2 erms invpcid xsaveopt arat md_clear arch_capabilities
